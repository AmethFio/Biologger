# %%
import simulation2 as si

# %%
data = si.generate_24h_data()

# %%
for act in data:
    print(act.items())
# Out:
# dict_items([('t', 1752745189), ('a', None)])
# dict_items([('t', 30), ('a', 2)])
# dict_items([('t', 42), ('a', 0)])
# dict_items([('t', 133), ('a', 1)])
# dict_items([('t', 73), ('a', 3)])
# dict_items([('t', 41), ('a', 2)])
# dict_items([('t', 39), ('a', 3)])
# dict_items([('t', 25), ('a', 2)])
# dict_items([('t', 44), ('a', 0)])
# dict_items([('t', 95), ('a', 3)])
# dict_items([('t', 29), ('a', 2)])
# dict_items([('t', 65), ('a', 0)])
# dict_items([('t', 96), ('a', 3)])
# dict_items([('t', 44), ('a', 3)])
# dict_items([('t', 35), ('a', 2)])
# dict_items([('t', 39), ('a', 2)])
# dict_items([('t', 55), ('a', 0)])
# dict_items([('t', 24), ('a', 2)])
# dict_items([('t', 27), ('a', 2)])
# dict_items([('t', 71), ('a', 0)])
# dict_items([('t', 35), ('a', 2)])
# dict_items([('t', 52), ('a', 4)])
# dict_items([('t', 35), ('a', 2)])
# dict_items([('t', 72), ('a', 0)])
# dict_items([('t', 62), ('a', 3)])
# dict_items([('t', 11), ('a', 0)])
# dict_items([('t', 19), ('a', 2)])
# ...
